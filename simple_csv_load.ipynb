# %%
# Just creating a simple barebones csv read / load into a dataframe and displaying it

# At a glance, it looks like the data doesn't have a specific item it starts tracking every league. Each table shows a different item being tracked first.
# Unsure if this will matter later on but it's something we may need/want to change.

# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# File Loading
necro_currency_loading = Path("resources/Necropolis.currency.csv")
affliction_currency_loading = Path("resources/Affliction.currency.csv")
sanctum_currency_loading = Path("resources/Sanctum.currency.csv")
crucible_currency_loading = Path("resources/Crucible.currency.csv")

# Read / Store in DFs
necro_CData = pd.read_csv(necro_currency_loading, delimiter=';')
affliction_CData = pd.read_csv(affliction_currency_loading, delimiter=';')
sanctum_CData = pd.read_csv(sanctum_currency_loading, delimiter=';')
crucible_CData = pd.read_csv(crucible_currency_loading, delimiter=';')

# %%
# Display Brief necro_CData DF Overview
necro_CData.head()
# Out:
#        League        Date            Get        Pay    Value Confidence
# 0  Necropolis  2024-03-29  Orb of Regret  Chaos Orb  1.00000       High
# 1  Necropolis  2024-03-30  Orb of Regret  Chaos Orb  0.49918       High
# 2  Necropolis  2024-03-31  Orb of Regret  Chaos Orb  0.50000       High
# 3  Necropolis  2024-04-01  Orb of Regret  Chaos Orb  0.47500       High
# 4  Necropolis  2024-04-02  Orb of Regret  Chaos Orb  0.47500       High

# %%
# Display Brief affliction_CData DF Overview
affliction_CData.head()
# Out:
#        League        Date             Get        Pay    Value Confidence
# 0  Affliction  2023-12-08  Orb of Alchemy  Chaos Orb  0.50000       High
# 1  Affliction  2023-12-09  Orb of Alchemy  Chaos Orb  0.20000       High
# 2  Affliction  2023-12-10  Orb of Alchemy  Chaos Orb  0.18000       High
# 3  Affliction  2023-12-11  Orb of Alchemy  Chaos Orb  0.13333       High
# 4  Affliction  2023-12-12  Orb of Alchemy  Chaos Orb  0.12500       High

# %%
# Display Brief sanctum_CData DF Overview
sanctum_CData.head()
# Out:
#     League        Date                Get        Pay    Value Confidence
# 0  Sanctum  2022-12-09  Sacrifice at Dusk  Chaos Orb  1.00000       High
# 1  Sanctum  2022-12-10  Sacrifice at Dusk  Chaos Orb  0.97870       High
# 2  Sanctum  2022-12-11  Sacrifice at Dusk  Chaos Orb  0.46180       High
# 3  Sanctum  2022-12-12  Sacrifice at Dusk  Chaos Orb  0.27212       High
# 4  Sanctum  2022-12-13  Sacrifice at Dusk  Chaos Orb  0.18200       High

# %%
# Display Brief crucible_CData DF Overview
crucible_CData.head()
# Out:
#      League        Date            Get        Pay    Value Confidence
# 0  Crucible  2023-04-07  Chromatic Orb  Chaos Orb  0.20000       High
# 1  Crucible  2023-04-08  Chromatic Orb  Chaos Orb  0.08333       High
# 2  Crucible  2023-04-09  Chromatic Orb  Chaos Orb  0.15789       High
# 3  Crucible  2023-04-10  Chromatic Orb  Chaos Orb  0.16667       High
# 4  Crucible  2023-04-11  Chromatic Orb  Chaos Orb  0.16667       High
